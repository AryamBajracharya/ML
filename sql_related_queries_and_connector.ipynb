# %%
import pandas as pd

Departments_data = {
'id': [1, 2, 3],
    'name': ['HR', 'Engineering', 'Sales']

}

Employees_data = {
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank'],
    'dept_id': [1, 2, 1, 3, 2, 3]

}
departments_data_df = pd.DataFrame(Departments_data)
employees_data_df = pd.DataFrame(Employees_data)

# %%
departments_data_df
# Out:
#    id         name
# 0   1           HR
# 1   2  Engineering
# 2   3        Sales

# %%
employees_data_df
# Out:
#    id     name  dept_id
# 0   1    Alice        1
# 1   2      Bob        2
# 2   3  Charlie        1
# 3   4    David        3
# 4   5      Eve        2
# 5   6    Frank        3

# %%
hr_dept_id = departments_data_df.loc[departments_data_df['name'] == 'HR', 'id'].values[0] # HR department id
hr_dept_id
# Out:
# np.int64(1)

# %%
hr_employees = employees_data_df[employees_data_df['dept_id'] == hr_dept_id] # Independent nested query
hr_employees
# Out:
#    id     name  dept_id
# 0   1    Alice        1
# 2   3  Charlie        1

# %%
hr_employee_names = hr_employees['name']

# %%
hr_employee_names
# Out:
# 0      Alice
# 2    Charlie
# Name: name, dtype: object

# %%
hr_employee_names = employees_data_df[employees_data_df['dept_id'].isin(departments_data_df[departments_data_df['name']=='HR']['id'])]['name']

# %%
hr_employee_names
# Out:
# 0      Alice
# 2    Charlie
# Name: name, dtype: object

# %%
import sqlite3

conn = sqlite3.connect('test.db')

cursor = conn.cursor()

cursor.execute(""" CREATE TABLE IF NOT EXISTS users (
               id INT AUTO INCREMENT PRIMARY KEY,
               name VARCHAR (100),
               email VARCHAR (100)
)
""")

conn.commit()

# %%
cursor.execute("""INSERT INTO users(name, email) VALUES ("Aryam", "aryambajracharya00@gmail.com"), ("Aavash", "aavashgyani00@gmail.com")""")

# %%
conn.commit() # Commit the changes to the database and it will show kati commit garyo teti nai tala fetch hunxa

# %%
cursor.execute("SELECT * FROM users")
for row in cursor.fetchall():  # Multiple rows so we used loop
    print(row)
# Out:
# (None, 'Aryam', 'aryambajracharya00@gmail.com')
# (None, 'Aryam', 'aryambajracharya00@gmail.com')
# (None, 'Aavash', 'aavashrandi00@gmail.com')
# (None, 'Aryam', 'aryambajracharya00@gmail.com')
# (None, 'Aavash', 'aavashgyani00@gmail.com')
